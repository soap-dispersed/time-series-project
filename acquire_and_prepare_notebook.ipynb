# %%
from imports import *
import warnings
warnings.filterwarnings('ignore')
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
def get_data():
    url = get_db_url('superstore_db')
    sql = '''
          SELECT ord.*,
                 cat.Category,
                 prod.`Product Name`,
                 cust.`Customer Name`,
                 reg.`Region Name`
              FROM orders ord
                LEFT JOIN categories cat USING(`Category ID`)
                LEFT JOIN products prod USING(`Product ID`)
                LEFT JOIN customers cust USING(`Customer ID`)
                LEFT JOIN regions reg USING(`Region ID`)
          '''
    df = pd.read_sql(sql, url)
    return df

# %%
df = get_data()

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  Postal Code  \
# 0   Consumer  United States        Henderson    Kentucky      42420.0
# 1   Consumer  United States        Henderson    Kentucky      42420.0
# 2  Corporate  United States      Los Angeles  California      90036.0
# 3   Consumer  United States  Fort Lauderdale     Florida      33311.0
# 4   Consumer  United States  Fort Lauderdale     Florida      33311.0
#
#         Product ID     Sales  Quantity  Discount    Profit  Category ID  \
# 0  FUR-BO-10001798  261.9600       2.0      0.00   41.9136            1
# 1  FUR-CH-10000454  731.9400       3.0      0.00  219.5820            2
# 2  OFF-LA-10000240   14.6200       2.0      0.00    6.8714            3
# 3  FUR-TA-10000577  957.5775       5.0      0.45 -383.0310            4
# 4  OFF-ST-10000760   22.3680       2.0      0.20    2.5164            5
#
#    Region ID         Category  \
# 0          1        Furniture
# 1          1        Furniture
# 2          2  Office Supplies
# 3          1        Furniture
# 4          1  Office Supplies
#
#                                                   Product Name  \
# 0                            Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back
# 2    Self-Adhesive Address Labels for Typewriters by Universal
# 3                Bretford CR4500 Series Slim Rectangular Table
# 4                               Eldon Fold 'N Roll Cart System
#
#      Customer Name Region Name
# 0      Claire Gute       South
# 1      Claire Gute       South
# 2  Darrin Van Huff        West
# 3   Sean O'Donnell       South
# 4   Sean O'Donnell       South

# %%
def prep_data(df):
    
    # rename columns: lower case, remove space
    for col in df.columns:
        df = df.rename(columns={col: col.lower().replace(' ', '_')})
        
    # cast date columns as datetime type
    df.order_date = pd.to_datetime(df.order_date)
    df.ship_date = pd.to_datetime(df.ship_date)
        
    # make datetime index
    df.index = df.order_date
    
    # add profit per product column
    df['profit_per_product'] = df.profit / df.quantity
    
    # add sales per product
    df['sales_per_product'] = df.sales / df.quantity

    return df

# %%
df = prep_data(df)

# %%
df.head()
# Out:
#                   order_id order_date  ship_date       ship_mode customer_id  \
# order_date
# 2016-11-08  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2016-11-08  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2016-06-12  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 2015-10-11  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 2015-10-11  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#               segment        country             city       state  \
# order_date
# 2016-11-08   Consumer  United States        Henderson    Kentucky
# 2016-11-08   Consumer  United States        Henderson    Kentucky
# 2016-06-12  Corporate  United States      Los Angeles  California
# 2015-10-11   Consumer  United States  Fort Lauderdale     Florida
# 2015-10-11   Consumer  United States  Fort Lauderdale     Florida
#
#             postal_code       product_id     sales  quantity  discount  \
# order_date
# 2016-11-08      42420.0  FUR-BO-10001798  261.9600       2.0      0.00
# 2016-11-08      42420.0  FUR-CH-10000454  731.9400       3.0      0.00
# 2016-06-12      90036.0  OFF-LA-10000240   14.6200       2.0      0.00
# 2015-10-11      33311.0  FUR-TA-10000577  957.5775       5.0      0.45
# 2015-10-11      33311.0  OFF-ST-10000760   22.3680       2.0      0.20
#
#               profit  category_id  region_id         category  \
# order_date
# 2016-11-08   41.9136            1          1        Furniture
# 2016-11-08  219.5820            2          1        Furniture
# 2016-06-12    6.8714            3          2  Office Supplies
# 2015-10-11 -383.0310            4          1        Furniture
# 2015-10-11    2.5164            5          1  Office Supplies
#
#                                                            product_name  \
# order_date
# 2016-11-08                            Bush Somerset Collection Bookcase
# 2016-11-08  Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back
# 2016-06-12    Self-Adhesive Address Labels for Typewriters by Universal
# 2015-10-11                Bretford CR4500 Series Slim Rectangular Table
# 2015-10-11                               Eldon Fold 'N Roll Cart System
#
#               customer_name region_name  profit_per_product  \
# order_date
# 2016-11-08      Claire Gute       South             20.9568
# 2016-11-08      Claire Gute       South             73.1940
# 2016-06-12  Darrin Van Huff        West              3.4357
# 2015-10-11   Sean O'Donnell       South            -76.6062
# 2015-10-11   Sean O'Donnell       South              1.2582
#
#             sales_per_product  month weekday
# order_date
# 2016-11-08           130.9800     11   1-Tue
# 2016-11-08           243.9800     11   1-Tue
# 2016-06-12             7.3100      6   6-Sun
# 2015-10-11           191.5155     10   6-Sun
# 2015-10-11            11.1840     10   6-Sun

# %%
def split_data(df):
    '''
    Splits data into train and test based on year.
    '''
    train = df['2014':'2016']
    test = df['2017']
    return train, test

# %%
train, test = split_data(df)

# %%
train.shape
# Out:
# (1238, 25)

# %%
test.shape
# Out:
# (496, 25)
